# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
df =pd.read_csv("Salary Data.csv")
df=df.dropna()
Target = df["Salary"]
Feature = df["Years of Experience"]

# %%
plt.scatter(Target,Feature,color='red',marker="*")

# %%
reg=LinearRegression()
reg.fit(df[["Years of Experience"]],Target)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([6844.51051448])

# %%
reg.intercept_
# Out:
# np.float64(31921.21691704422)

# %%
y = 6844.51051448 * 5 + 31921.21691704422
print(y)
# Out:
# 66143.76948944422

# %%
data =pd.read_csv("Salary Data.csv")
data =data[data["Years of Experience"] == 6]["Salary"]
data
# Out:
# 12      65000.0
# 29      90000.0
# 70      65000.0
# 77     100000.0
# 89      55000.0
# 113     90000.0
# 115     95000.0
# 186     95000.0
# 215    100000.0
# 244     70000.0
# 256    100000.0
# 316     80000.0
# Name: Salary, dtype: float64

# %%
plt.scatter(Feature,Target,marker="*")
plt.plot(Feature,reg.predict(df[["Years of Experience"]]),color='red')

# %%
import matplotlib.pyplot as plt

# Scatter plot (data points)
plt.scatter(Feature, Target, marker="*", label="Actual Data")

# Line plot (predicted regression line)
plt.plot(Feature, reg.predict(df[["Years of Experience"]]), color="red", label="Regression Line")

# Labels and title
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.title("Experience vs Salary")
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt 
from sklearn.linear_model import LinearRegression

df= pd.read_csv("Salary Data.csv")
df=df.dropna()

# %%
Feature = df["Age"]
Target = df["Salary"]

plt.scatter(Feature,Target,marker="*")

# %%
reg=LinearRegression()
reg.fit(df[["Age"]],Target)
# Out:
# LinearRegression()

# %%
import matplotlib.pyplot as plt

# Scatter plot (data points)
plt.scatter(Feature, Target, marker="*", label="Actual Data")

# Line plot (predicted regression line)
plt.plot(Feature, reg.predict(df[["Age"]]), color="red", label="Regression Line")

# Labels and title
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.title("Experience vs Salary")
plt.legend()
plt.show()
